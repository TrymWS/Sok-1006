# %% [markdown]
# Arbeidskrav 1, Sok-1006, Vår 2023.

# %%
import numpy as np
import sympy as sp
import pandas as pd
from matplotlib import pyplot as plt

df=pd.read_csv("https://uit-sok-1006-v23.github.io/data/suits_watermelons.csv",delimiter=";")

# %%
df
# Out:
#     Year     log q     log h     log p   log p_c   log p_v     log w  \
# 0   1930  4.448623  4.379545  4.761777  2.247338  0.845054  3.366401
# 1   1931  4.356519  4.333493  4.614410  1.733858  2.726278  3.136141
# 2   1932  4.204548  4.054879  4.368032  1.874316  2.588122  2.832198
# 3   1933  4.031853  4.008827  4.531517  2.318718  2.286482  2.772330
# 4   1934  4.096325  4.094023  4.644344  2.514439  1.475967  2.917394
# 5   1935  4.195337  4.156193  4.563753  2.406217  1.892737  2.970354
# 6   1936  4.135470  4.128562  4.851578  2.514439  1.897342  2.995683
# 7   1937  4.262113  4.225271  4.662765  2.129905  2.079248  3.113115
# 8   1938  4.259810  4.202245  4.690396  2.150628  3.044037  3.090089
# 9   1939  4.144680  4.137772  4.777895  2.208193  1.701621  3.113115
# 10  1940  4.345006  4.282836  4.690396  2.291087  2.535163  3.136141
# 11  1941  4.165403  4.165403  4.897630  2.834501  3.161470  3.295021
# 12  1942  4.034155  4.034155  5.480188  2.947328  3.893697  3.525281
# 13  1943  3.882184  3.882184  6.097285  2.988775  3.642713  3.794685
# 14  1944  4.259810  4.259810  5.908472  3.032524  2.390099  3.988103
# 15  1945  4.289744  4.289744  6.016694  3.115418  1.853593  4.126259
# 16  1946  4.393361  4.388756  5.949918  3.486136  3.430874  4.262113
# 17  1947  4.395663  4.326585  5.765710  3.463110  3.460808  4.331191
# 18  1948  4.301257  4.301257  5.963734  3.414756  3.981195  4.381848
# 19  1949  4.361124  4.358822  5.742684  3.352586  2.733186  4.356519
# 20  1950  4.411782  4.326585  5.777223  3.691068  1.883527  4.370335
# 21  1951  4.423295  4.414084  5.910774  3.635805       NaN       NaN
#
#        log n  log(y/n)   log p_f
# 0   4.812434  6.403531  2.535163
# 1   4.819342  6.244651  2.546676
# 2   4.826250  5.966037  2.599635
# 3   4.833157  5.896959  2.645687
# 4   4.840065  6.018996  2.624964
# 5   4.844670  6.129521  2.710160
# 6   4.853881  6.246954  2.703252
# 7   4.858486  6.311427  2.705555
# 8   4.865394  6.226230  2.753910
# 9   4.874604  6.288401  2.691739
# 10  4.883815  6.355176  2.753910
# 11  4.893025  6.546292  2.758515
# 12  4.904538  6.769644  2.744699
# 13  4.918354  6.884774  2.643385
# 14  4.929867  6.965365  2.634174
# 15  4.941380  6.979181  2.696345
# 16  4.950590  7.025233  2.694042
# 17  4.971313  7.066679  2.869040
# 18  4.987432  7.154178  3.087787
# 19  5.005852  7.140363  3.168378
# 20  5.021971  7.214046  3.219035
# 21  5.040391  7.290032  3.267389

# %% [markdown]
# Part 7.1 Drawing supply and demand diagrams

# %% [markdown]
# 1. To make charts that look like those in Figure 1 in the paper, you need to convert the relevant variables to their actual values. Follow R walk-through 7.1 to answer the following questions.

# %% [markdown]
# (a) Create two new variables containing the actual values of P and Q.

# %%
# Antilog av verdiene for pris, kvantum og høsting
df["P"] = np.exp(df["log p"])
df["Q"] = np.exp(df["log q"])
df["H"] = np.exp(df["log h"])

# %%
df
# Out:
#     Year     log q     log h     log p   log p_c   log p_v     log w  \
# 0   1930  4.448623  4.379545  4.761777  2.247338  0.845054  3.366401
axs[1].plot(df.Year, df["Q"], color="blue")
axs[1].plot(df.Year, df["H"], color="red", linestyle="--")

# Scatterplot av pris og kvantum
axs[0].scatter(df.Year, df["P"],label='Price')
axs[1].scatter(df.Year, df["Q"],label='Crop', color="blue", marker="s")
axs[1].scatter(df.Year, df["H"],label='Harvest', color="red", marker="D")

# Legger til titler
axs[0].set_title('(a) Price p (dollars per thousand)')
axs[1].set_title('(b) Crop q and harvest h (millions)')

# Legger til labels
axs[0].set_xlabel('Year', size=15)
axs[1].set_xlabel('Year', size=15)

# Legger til labels
axs[0].set_ylabel('Price')
axs[1].set_ylabel('Crop and harvest')

# Legger til legend
axs[0].legend(loc='upper center')
axs[1].legend(loc='upper center')


plt.show()

# %% [markdown]
# 2. Plot supply and demand curves:

# %% [markdown]
# (a) Create a table as shown in Figure 7.4. The first column contains values of Q from 20 to 100, in intervals of 5. (Remember that quantity is measured in millions, so Q = 20 corresponds to 20 million watermelons.)

# %% [markdown]
# (b) Convert the values of Q to natural log format (second column of your table) and use these values, along with the numbers in the equations above, to calculate the corresponding values of log P for supply (third column) and demand (fourth column).

# %% [markdown]
# (c) Convert the log P numbers into the actual prices (fifth and sixth columns).

# %%
Q=[20]
Interval = 5

while Q[-1] < 100:
    Q.append(Q[-1]+Interval)

df_2 = pd.DataFrame(Q)

df_2.columns = ["Q"]

df_2["Log Q"] = np.log(df_2["Q"])

df_2["Supply (Log P)"] = -2.0 + 1.7*df_2["Log Q"]
df_2["Demand (log P)"] = 8.5 - 0.82*df_2["Log Q"]

df_2["Supply_P"] = np.exp(df_2["Supply (Log P)"])
df_2["Demand_P"] = np.exp(df_2["Demand (log P)"])

print(df_2)
# Out:
#       Q     Log Q  Supply (Log P)  Demand (log P)    Supply_P    Demand_P
# 0    20  2.995732        3.092745        6.043500   22.037485  421.365040
# 1    25  3.218876        3.472089        5.860522   32.203943  350.907208
# 2    30  3.401197        3.782036        5.711018   43.905322  302.178574
# 3    35  3.555348        4.044092        5.584615   57.059336  266.297629
# 4    40  3.688879        4.271095        5.475119   71.600000  238.678832
# 5    45  3.806662        4.471326        5.378537   87.472655  216.704952
# 6    50  3.912023        4.650439        5.292141  104.630920  198.768561
# 7    55  4.007333        4.812466        5.213987  123.034698  183.825472
# 8    60  4.094345        4.960386        5.142637  142.648813  171.166618
# 9    65  4.174387        5.096458        5.077002  163.442028  160.292847
# 10   70  4.248495        5.222442        5.016234  185.386329  150.842146
# 11   75  4.317488        5.339730        4.959660  208.456376  142.545286
# 12   80  4.382027        5.449445        4.906738  232.629086  135.197701
# 13   85  4.442651        5.552507        4.857026  257.883295  128.641050
# 14   90  4.499810        5.649676        4.810156  284.199495  122.750774
# 15   95  4.553877        5.741591        4.765821  311.559620  117.427480
# 16  100  4.605170        5.828789        4.723760  339.946862  112.590850

# %% [markdown]
# (d) Plot your calculated supply and demand curves on a line chart, with price (P) on the vertical axis and quantity (Q) on the horizontal axis. Make sure to label your curves (for example, using a legend).

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(df_2.Supply_P, df_2["Supply_P"], label="Supply", color="lightblue")
ax.plot(df_2.Supply_P, df_2["Demand_P"], label="Demand", color="red")

ax.set_xlabel("Quantity")
ax.set_ylabel("Price")

ax.legend(loc="upper center")

# %% [markdown]
# 3. Add the new supply curve to your line chart and interpret the outcomes, as follows:

# %% [markdown]
# (a) Create a new column in your table from Question 2 called ‘New supply (log P)’, showing the supply in terms of log prices after the shock. Make another column called ‘New supply (P)’ showing the supply in terms of the actual price in dollars.

# %%
df_2["New Supply (Log P)"] = -2.0 + 1.7*df_2["Log Q"] +0.4
df_2["New_Supply_P"] = np.exp(df_2["New Supply (Log P)"])

df_2
# Out:
#       Q     Log Q  Supply (Log P)  Demand (log P)    Supply_P    Demand_P  \
# 0    20  2.995732        3.092745        6.043500   22.037485  421.365040
# 1    25  3.218876        3.472089        5.860522   32.203943  350.907208
# 2    30  3.401197        3.782036        5.711018   43.905322  302.178574
# 3    35  3.555348        4.044092        5.584615   57.059336  266.297629
# 4    40  3.688879        4.271095        5.475119   71.600000  238.678832
# 5    45  3.806662        4.471326        5.378537   87.472655  216.704952
# 6    50  3.912023        4.650439        5.292141  104.630920  198.768561
# 7    55  4.007333        4.812466        5.213987  123.034698  183.825472
# 8    60  4.094345        4.960386        5.142637  142.648813  171.166618
# 9    65  4.174387        5.096458        5.077002  163.442028  160.292847
# 10   70  4.248495        5.222442        5.016234  185.386329  150.842146
# 11   75  4.317488        5.339730        4.959660  208.456376  142.545286
# 12   80  4.382027        5.449445        4.906738  232.629086  135.197701
# 13   85  4.442651        5.552507        4.857026  257.883295  128.641050
# 14   90  4.499810        5.649676        4.810156  284.199495  122.750774
# 15   95  4.553877        5.741591        4.765821  311.559620  117.427480
# 16  100  4.605170        5.828789        4.723760  339.946862  112.590850
#
#     New Supply (Log P)  New_Supply_P
# 0             3.492745     32.876064
# 1             3.872089     48.042638
# 2             4.182036     65.499044
# 3             4.444092     85.122526
# 4             4.671095    106.814648
# 5             4.871326    130.493867
# 6             5.050439    156.090990
# 7             5.212466    183.546201
# 8             5.360386    212.807022
# 9             5.496458    243.826854
# 10            5.622442    276.563904
# 11            5.739730    310.980371
# 12            5.849445    347.041816
# 13            5.952507    384.716668
# 14            6.049676    423.975826
# 15            6.141591    464.792336
# 16            6.228789    507.141124

# %% [markdown]
# (b) Add the New supply (P) values to your line chart and verify that your chart looks as expected. Make sure to label the new supply curve.

# %%
fig, ax = plt.subplots(figsize=(10,5))

ax.plot(df_2.Supply_P, df_2["New_Supply_P"], label="New Supply", color="lightblue", linestyle="--")
ax.plot(df_2.Supply_P, df_2["Supply_P"], label="Supply", color="lightblue")
ax.plot(df_2.Supply_P, df_2["Demand_P"], label="Demand", color="red")

ax.set_xlabel("Quantity")
ax.set_ylabel("Price")

ax.legend(loc="upper center")

# %% [markdown]
# Part 7.2 Interpreting supply and demand curves

# %% [markdown]
# # Kom ikke lenger enn hit

# %% [markdown]
# 1. Use the supply and demand equations from Part 7.1 which are shown here, and carry out the following:

# %% [markdown]
# (a) Calculate the price elasticity of supply (the percentage change in quantity supplied divided by the percentage change in price) and comment on its size (in absolute value). (Hint: You will have to rearrange the equation so that log Q is in terms of log P.)

# %% [markdown]
# (b) Calculate the price elasticity of demand in the same way and comment on its size (in absolute value).

# %% [markdown]
# 2. With reference to Figure 7.6, for each variable in the supply equation, give an economic interpretation of the coefficient (for example, explain the effect on the farmers’ supply decision) and (where relevant) relate the coefficient to an elasticity.

# %% [markdown]
# 3. Using the demand equation and Figure 7.7 below, give an economic interpretation of each coefficient and (where relevant) relate the coefficient to an elasticity.

# %% [markdown]
# 4. Given the supply and demand equations in the watermelon model, give two examples of an exogenous demand shock and explain why they are exogenous.
